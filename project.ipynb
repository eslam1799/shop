# %%
import pandas as pd 
import numpy as np 
import pyodbc 

import warnings
warnings.filterwarnings("ignore")

# %%
import pyodbc
print(pyodbc.drivers())
# Out:
# ['SQL Server', 'SQL Server Native Client RDA 11.0', 'ODBC Driver 17 for SQL Server', 'Microsoft Access Driver (*.mdb, *.accdb)', 'Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)', 'Microsoft Access Text Driver (*.txt, *.csv)', 'Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)', 'ODBC Driver 18 for SQL Server']

# %%
conn_str = (
    'DRIVER={ODBC Driver 17 for SQL Server};'
    'SERVER=localhost\SQLEXPRESS;'
    'DATABASE=eslam;'
    'Trusted_Connection=yes'
)

# %%
conn = pyodbc.connect(conn_str)

# %%
query = "SELECT * FROM dbo.shopping_trends"
df = pd.read_sql(query, conn)

df
# Out:
#       Customer_ID  Age  Gender Item_Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase_Amount_USD       Location Size      Color  Season  \
# 0                      53       Kentucky    L       Gray  Winter
# 1                      64          Maine    L     Maroon  Winter
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# libriries

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# EDA

# %%
df.describe()
# Out:
#        Customer_ID          Age  Purchase_Amount_USD  Review_Rating  \
# count  3900.000000  3900.000000          3900.000000    3900.000000
# mean   1950.500000    44.068462            59.764359       3.749949
# std    1125.977353    15.207589            23.685392       0.716223
# min       1.000000    18.000000            20.000000       2.500000
# 25%     975.750000    31.000000            39.000000       3.100000
# 50%    1950.500000    44.000000            60.000000       3.700000
# 75%    2925.250000    57.000000            81.000000       4.400000
# max    3900.000000    70.000000           100.000000       5.000000
#
#        Previous_Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.shape
# Out:
# (3900, 19)

# %%
y=df.dtypes

# %%
x=df['Customer_ID'].duplicated()
x.value_counts()
# Out:
# Customer_ID
# False    3900
# Name: count, dtype: int64

# %%
numeric_columns = df.select_dtypes(include=['int', 'float']).columns.tolist()
object_columns = df.select_dtypes(include='object').columns.tolist()

print("Numeric Columns:", numeric_columns)
print("Object Columns:", object_columns)
# Out:
# Numeric Columns: ['Customer_ID', 'Age', 'Purchase_Amount_USD', 'Review_Rating', 'Previous_Purchases']
# Object Columns: ['Gender', 'Item_Purchased', 'Category', 'Location', 'Size', 'Color', 'Season', 'Subscription_Status', 'Payment_Method', 'Shipping_Type', 'Discount_Applied', 'Promo_Code_Used', 'Preferred_Payment_Method', 'Frequency_of_Purchases']

# %%
df.head()
# Out:
#    Customer_ID  Age Gender Item_Purchased  Category  Purchase_Amount_USD  \
# 0            1   55   Male         Blouse  Clothing                   53
# 1            2   19   Male        Sweater  Clothing                   64
# 2            3   50   Male          Jeans  Clothing                   73
# 3            4   21   Male        Sandals  Footwear                   90
# 4            5   45   Male         Blouse  Clothing                   49
#
#         Location Size      Color  Season  Review_Rating Subscription_Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#   Payment_Method  Shipping_Type Discount_Applied Promo_Code_Used  \
# ...

# %%
plt.figure(figsize=(5, 4))
plt.boxplot(df['Purchase_Amount_USD'])
plt.xlabel('AGE')
plt.grid(True)
plt.show()

# %%
column=['Age', 'Gender', 'Item_Purchased', 'Category',
       'Purchase_Amount_USD', 'Location', 'Size', 'Color', 'Season',
       'Review_Rating', 'Subscription_Status', 'Payment_Method',
       'Shipping_Type', 'Discount_Applied', 'Promo_Code_Used',
       'Previous_Purchases', 'Preferred_Payment_Method',
       'Frequency_of_Purchases']

# %%
df.dtypes
# Out:
# Customer_ID                   int64
# Age                           int64
# Gender                       object
# Item_Purchased               object
# Category                     object
# Purchase_Amount_USD           int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review_Rating               float64
# Subscription_Status          object
# Payment_Method               object
# Shipping_Type                object
# Discount_Applied             object
# Promo_Code_Used              object
# Previous_Purchases            int64
# Preferred_Payment_Method     object
# Frequency_of_Purchases       object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Customer_ID                 0
# Age                         0
# Gender                      0
# Item_Purchased              0
# Category                    0
# Purchase_Amount_USD         0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review_Rating               0
# Subscription_Status         0
# Payment_Method              0
# Shipping_Type               0
# Discount_Applied            0
# Promo_Code_Used             0
# Previous_Purchases          0
# Preferred_Payment_Method    0
# Frequency_of_Purchases      0
# dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                      Customer_ID       Age  Purchase_Amount_USD  \
# Customer_ID             1.000000 -0.004079             0.011048
# Age                    -0.004079  1.000000            -0.010424
# Purchase_Amount_USD     0.011048 -0.010424             1.000000
# Review_Rating           0.001343 -0.021949             0.030776
# Previous_Purchases     -0.039159  0.040445             0.008063
#
#                      Review_Rating  Previous_Purchases
# Customer_ID               0.001343           -0.039159
# Age                      -0.021949            0.040445
# Purchase_Amount_USD       0.030776            0.008063
# Review_Rating             1.000000            0.004229
# Previous_Purchases        0.004229            1.000000

# %%
for i in column:
  if df[i].dtype=='object':
    plt.figure(figsize=(10,5))
    sns.barplot(df[i])
    plt.title(i)
    plt.show()
  elif df[i].dtype=='int64'or'float64':
    plt.figure(figsize=(10,5))
    sns.boxplot(df[i])
    plt.title(i)
    plt.show()
  else:
    break

# %%
for i in column:
  print(i)
  print(df[i].unique())
  print()
# Out:
# Age
# [55 19 50 21 45 46 63 27 26 57 53 30 61 65 64 25 52 66 31 56 18 38 54 33
#  36 35 29 70 69 67 20 39 42 68 49 59 47 40 41 48 22 24 44 37 58 32 62 51
#  28 43 34 23 60]
#
# Gender
# ['Male' 'Female']
#
# Item_Purchased
# ['Blouse' 'Sweater' 'Jeans' 'Sandals' 'Sneakers' 'Shirt' 'Shorts' 'Coat'
#  'Handbag' 'Shoes' 'Dress' 'Skirt' 'Sunglasses' 'Pants' 'Jacket' 'Hoodie'
#  'Jewelry' 'T-shirt' 'Scarf' 'Hat' 'Socks' 'Backpack' 'Belt' 'Boots'
#  'Gloves']
#
# Category
# ['Clothing' 'Footwear' 'Outerwear' 'Accessories']
#
# Purchase_Amount_USD
# [ 53  64  73  90  49  20  85  34  97  31  68  72  51  81  36  38  48  62
#   37  88  22  25  56  94  79  67  91  33  69  45  60  76  39 100  21  43
#   54  55  30  28  59  24  83  46  70  29  26  58  96  40  32  95  41  47
#   99  87  92  98  89  35  75  65  86  84  77  27  23  74  80  42  61  82
#   78  93  50  57  66  44  52  71  63]
#
# Location
# ['Kentucky' 'Maine' 'Massachusetts' 'Rhode Island' 'Oregon' 'Wyoming'
# ...

# %%
np.mean(df['Age'])      # Average
np.median(df['Age'])    # Middle value
np.std(df['Age'])       # Standard deviation
# Out:
# 15.20563931125243

# %%
df['Age'].describe()
# Out:
# count    3900.000000
# mean       44.068462
# std        15.207589
# min        18.000000
# 25%        31.000000
# 50%        44.000000
# 75%        57.000000
# max        70.000000
# Name: Age, dtype: float64

# %%
df.describe()
# Out:
#        Customer_ID          Age  Purchase_Amount_USD  Review_Rating  \
# count  3900.000000  3900.000000          3900.000000    3900.000000
# mean   1950.500000    44.068462            59.764359       3.749949
# std    1125.977353    15.207589            23.685392       0.716223
# min       1.000000    18.000000            20.000000       2.500000
# 25%     975.750000    31.000000            39.000000       3.100000
# 50%    1950.500000    44.000000            60.000000       3.700000
# 75%    2925.250000    57.000000            81.000000       4.400000
# max    3900.000000    70.000000           100.000000       5.000000
#
#        Previous_Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000
